# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (2.2.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\nick\anaconda3\envs\pythonadv\lib\site-packages (1.0.1)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head(20)
# Out:
#    koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CONFIRMED              0              0              0
# 1   FALSE POSITIVE              0              1              0
# 2   FALSE POSITIVE              0              1              0
# 3        CONFIRMED              0              0              0
# 4        CONFIRMED              0              0              0
# 5        CONFIRMED              0              0              0
# 6        CONFIRMED              0              0              0
# 7        CONFIRMED              0              0              0
# 8        CONFIRMED              0              1              0
# 9        CONFIRMED              0              0              0
# 10       CONFIRMED              0              0              0
# 11  FALSE POSITIVE              0              1              0
# 12  FALSE POSITIVE              0              1              0
# 13  FALSE POSITIVE              0              1              0
# 14       CONFIRMED              0              0              0
# 15       CONFIRMED              0              0              0
# 16  FALSE POSITIVE              0              1              1
# 17       CONFIRMED              0              0              0
# 18  FALSE POSITIVE              0              1              0
# 19       CONFIRMED              0              0              0
#
#     koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0               0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1               0   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2               0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3               0    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4               0    4.134435     1.050000e-05    -1.050000e-05   172.979370
# 5               0    2.566589     1.780000e-05    -1.780000e-05   179.554370
# 6               0   16.068647     1.090000e-05    -1.090000e-05   173.621937
# 7               0    2.470613     2.700000e-08    -2.700000e-08   122.763305
# 8               0    2.204735     4.300000e-08    -4.300000e-08   121.358542
# 9               0    3.522498     1.980000e-07    -1.980000e-07   121.119423
# 10              0    3.709214     6.540000e-06    -6.540000e-06   133.983180
# 11              0   11.521446     1.980000e-06    -1.980000e-06   170.839688
# 12              0   19.221389     1.120000e-06    -1.120000e-06   184.552164
# 13              0   16.469838     1.360000e-05    -1.360000e-05   180.881761
# 14              0    9.273582     1.040000e-05    -1.040000e-05   173.258155
# 15              0    6.029303     5.510000e-06    -5.510000e-06   171.602959
# 16              1    2.696371     7.530000e-06    -7.530000e-06   170.737690
# 17              0    3.941052     1.090000e-05    -1.090000e-05   136.086620
# 18              0  386.603053     1.369000e-04    -1.369000e-04   166.342079
# 19              0   21.676992     7.010000e-05    -7.010000e-05   171.535940
#
#     koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0           0.003520  ...             -81      4.467           0.064
# 1           0.000581  ...            -176      4.544           0.044
# 2           0.000115  ...            -174      4.564           0.053
# 3           0.001130  ...            -211      4.438           0.070
# 4           0.001900  ...            -232      4.486           0.054
# 5           0.004610  ...            -232      4.486           0.054
# 6           0.000517  ...             -83      4.485           0.083
# 7           0.000009  ...             -78      4.457           0.024
# 8           0.000016  ...             -89      4.019           0.033
# 9           0.000047  ...            -137      4.169           0.055
# 10          0.001430  ...            -117      4.407           0.085
# 11          0.000131  ...            -172      4.554           0.033
# 12          0.000045  ...            -200      4.496           0.052
# 13          0.000623  ...            -153      4.517           0.088
# 14          0.000877  ...            -146      4.583           0.065
# 15          0.000713  ...            -123      4.648           0.020
# 16          0.002340  ...            -149      4.504           0.090
# 17          0.002330  ...             -77      4.440           0.098
# 18          0.000299  ...             -79      4.081           0.014
# 19          0.002580  ...             -79      4.500           0.075
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# 5           -0.229     0.972          0.315         -0.105  296.28613
# 6           -0.028     0.848          0.033         -0.072  286.99948
# 7           -0.024     0.964          0.038         -0.038  286.80847
# 8           -0.027     1.952          0.099         -0.110  292.24728
# 9           -0.045     1.451          0.110         -0.110  281.28812
# 10          -0.114     1.022          0.143         -0.107  295.64871
# 11          -0.176     0.848          0.224         -0.075  297.07993
# 12          -0.208     0.947          0.308         -0.096  295.81454
# 13          -0.072     0.786          0.088         -0.088  297.15442
# 14          -0.035     0.696          0.056         -0.068  288.13824
# 15          -0.056     0.672          0.062         -0.036  283.71088
# 16          -0.060     0.819          0.067         -0.082  283.76547
# 17          -0.045     0.910          0.057         -0.086  292.37613
# 18          -0.014     1.580          0.064         -0.064  292.27374
# 19          -0.020     0.828          0.032         -0.065  290.46512
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# 5   48.224670      15.714
# 6   48.375790      15.841
# 7   49.316399      11.338
# 8   47.969521      10.463
# 9   42.451080      13.563
# 10  48.495560      12.772
# 11  47.597401      15.472
# 12  47.690350      15.341
# 13  47.668701      15.788
# 14  47.724449      15.302
# 15  47.863270      15.784
# 16  47.804298      15.269
# 17  47.880989      15.416
# 18  37.671558      12.394
# 19  47.929180      15.377
#
# [20 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df.drop(['koi_disposition'], axis=1)
selected_features
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0            -0.003520  ...             -81      4.467           0.064
# 1            -0.000581  ...            -176      4.544           0.044
# 2            -0.000115  ...            -174      4.564           0.053
# 3            -0.001130  ...            -211      4.438           0.070
# 4            -0.001900  ...            -232      4.486           0.054
# ...                ...  ...             ...        ...             ...
# 6986         -0.015700  ...            -152      4.296           0.231
# 6987         -0.000170  ...            -166      4.529           0.035
# 6988         -0.007690  ...            -220      4.444           0.056
# 6989         -0.002850  ...            -236      4.447           0.056
# 6990         -0.010800  ...            -225      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.176     0.868          0.233         -0.078  297.00482
# 2             -0.168     0.791          0.201         -0.067  285.53461
# 3             -0.210     1.046          0.334         -0.133  288.75488
# 4             -0.229     0.972          0.315         -0.105  296.28613
# ...              ...       ...            ...            ...        ...
# 6986          -0.189     1.088          0.313         -0.228  298.74921
# 6987          -0.196     0.903          0.237         -0.079  297.18875
# 6988          -0.224     1.031          0.341         -0.114  286.50937
# 6989          -0.224     1.041          0.341         -0.114  294.16489
# 6990          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Set X and y variables
y = df["koi_disposition"]
X = selected_features
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Split data into training and testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3563         -0.004110  ...            -133      4.387           0.066
# 4099         -0.004460  ...            -144      4.519           0.078
# 5460         -0.000096  ...            -140      4.594           0.054
# 1091         -0.005290  ...            -112      4.447           0.072
# 5999         -0.028600  ...            -233      4.145           0.164
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3563          -0.123     1.092          0.181         -0.097  298.09543
# 4099          -0.052     0.804          0.056         -0.076  295.73535
# 5460          -0.027     0.683          0.054         -0.060  292.18417
# 1091          -0.108     0.954          0.135         -0.083  283.11377
# 5999          -0.164     1.608          0.905         -0.383  294.93198
#
#             dec  koi_kepmag
# 3563  44.737061      13.204
# 4099  42.576248      15.514
# 5460  49.310040      15.414
# 1091  48.131390      13.328
# 5999  39.812420      12.964
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and layers
model = Sequential()
model.add(Dense(units = 100, activation ='relu', input_dim=40))
model.add(Dense(units = 100, activation ='relu'))
model.add(Dense(units = 3, activation='softmax'))

# %%
# compile the model
model.compile(optimizer ='adam',
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs= 100,
    shuffle= True,
    verbose= 2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 2s - loss: 0.6018 - accuracy: 0.7040
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.3814 - accuracy: 0.8035
# Epoch 3/100
# 5243/5243 - 1s - loss: 0.3647 - accuracy: 0.8165
# Epoch 4/100
# 5243/5243 - 1s - loss: 0.3608 - accuracy: 0.8180
# Epoch 5/100
# 5243/5243 - 1s - loss: 0.3467 - accuracy: 0.8293
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3374 - accuracy: 0.8398
# Epoch 7/100
# 5243/5243 - 1s - loss: 0.3333 - accuracy: 0.8390
# Epoch 8/100
# 5243/5243 - 1s - loss: 0.3314 - accuracy: 0.8457
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3294 - accuracy: 0.8426
# Epoch 10/100
# 5243/5243 - 1s - loss: 0.3182 - accuracy: 0.8489
# Epoch 11/100
# 5243/5243 - 1s - loss: 0.3196 - accuracy: 0.8547
# Epoch 12/100
# 5243/5243 - 1s - loss: 0.3118 - accuracy: 0.8564
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3102 - accuracy: 0.8581
# Epoch 14/100
# 5243/5243 - 1s - loss: 0.3113 - accuracy: 0.8600
# Epoch 15/100
# 5243/5243 - 1s - loss: 0.3044 - accuracy: 0.8648
# Epoch 16/100
# 5243/5243 - 1s - loss: 0.3085 - accuracy: 0.8604
# Epoch 17/100
# 5243/5243 - 1s - loss: 0.2989 - accuracy: 0.8642
# Epoch 18/100
# 5243/5243 - 1s - loss: 0.2986 - accuracy: 0.8642
# Epoch 19/100
# 5243/5243 - 1s - loss: 0.2901 - accuracy: 0.8701
# Epoch 20/100
# 5243/5243 - 1s - loss: 0.2883 - accuracy: 0.8720
# Epoch 21/100
# 5243/5243 - 0s - loss: 0.2878 - accuracy: 0.8758
# Epoch 22/100
# 5243/5243 - 1s - loss: 0.2932 - accuracy: 0.8709
# Epoch 23/100
# 5243/5243 - 1s - loss: 0.2876 - accuracy: 0.8699
# Epoch 24/100
# 5243/5243 - 1s - loss: 0.2841 - accuracy: 0.8724
# Epoch 25/100
# 5243/5243 - 0s - loss: 0.2891 - accuracy: 0.8770
# Epoch 26/100
# 5243/5243 - 1s - loss: 0.2827 - accuracy: 0.8766
# Epoch 27/100
# 5243/5243 - 1s - loss: 0.2837 - accuracy: 0.8766
# Epoch 28/100
# 5243/5243 - 0s - loss: 0.2809 - accuracy: 0.8783
# Epoch 29/100
# 5243/5243 - 0s - loss: 0.2772 - accuracy: 0.8833
# Epoch 30/100
# 5243/5243 - 1s - loss: 0.2812 - accuracy: 0.8755
# Epoch 31/100
# 5243/5243 - 1s - loss: 0.2763 - accuracy: 0.8777
# Epoch 32/100
# 5243/5243 - 1s - loss: 0.2767 - accuracy: 0.8785
# Epoch 33/100
# 5243/5243 - 1s - loss: 0.2701 - accuracy: 0.8823
# Epoch 34/100
# 5243/5243 - 1s - loss: 0.2669 - accuracy: 0.8850
# Epoch 35/100
# 5243/5243 - 1s - loss: 0.2747 - accuracy: 0.8776
# Epoch 36/100
# 5243/5243 - 1s - loss: 0.2700 - accuracy: 0.8848
# Epoch 37/100
# 5243/5243 - 1s - loss: 0.2669 - accuracy: 0.8852
# Epoch 38/100
# 5243/5243 - 1s - loss: 0.2794 - accuracy: 0.8756
# Epoch 39/100
# 5243/5243 - 1s - loss: 0.2709 - accuracy: 0.8814
# Epoch 40/100
# 5243/5243 - 1s - loss: 0.2579 - accuracy: 0.8852
# Epoch 41/100
# 5243/5243 - 1s - loss: 0.2746 - accuracy: 0.8793
# Epoch 42/100
# 5243/5243 - 1s - loss: 0.2673 - accuracy: 0.8751
# Epoch 43/100
# 5243/5243 - 1s - loss: 0.2608 - accuracy: 0.8867
# Epoch 44/100
# 5243/5243 - 0s - loss: 0.2621 - accuracy: 0.8854
# Epoch 45/100
# 5243/5243 - 0s - loss: 0.2630 - accuracy: 0.8825
# Epoch 46/100
# 5243/5243 - 0s - loss: 0.2584 - accuracy: 0.8842
# Epoch 47/100
# 5243/5243 - 1s - loss: 0.2590 - accuracy: 0.8850
# Epoch 48/100
# 5243/5243 - 0s - loss: 0.2587 - accuracy: 0.8829
# Epoch 49/100
# 5243/5243 - 1s - loss: 0.2601 - accuracy: 0.8877
# Epoch 50/100
# 5243/5243 - 0s - loss: 0.2511 - accuracy: 0.8899
# Epoch 51/100
# 5243/5243 - 1s - loss: 0.2556 - accuracy: 0.8854
# Epoch 52/100
# 5243/5243 - 1s - loss: 0.2521 - accuracy: 0.8913
# Epoch 53/100
# 5243/5243 - 1s - loss: 0.2518 - accuracy: 0.8907
# Epoch 54/100
# 5243/5243 - 0s - loss: 0.2522 - accuracy: 0.8894
# Epoch 55/100
# 5243/5243 - 1s - loss: 0.2542 - accuracy: 0.8837
# Epoch 56/100
# 5243/5243 - 1s - loss: 0.2511 - accuracy: 0.8888
# Epoch 57/100
# 5243/5243 - 1s - loss: 0.2597 - accuracy: 0.8821
# Epoch 58/100
# 5243/5243 - 1s - loss: 0.2614 - accuracy: 0.8795
# Epoch 59/100
# 5243/5243 - 1s - loss: 0.2538 - accuracy: 0.8863
# Epoch 60/100
# 5243/5243 - 1s - loss: 0.2514 - accuracy: 0.8858
# Epoch 61/100
# 5243/5243 - 1s - loss: 0.2454 - accuracy: 0.8949
# Epoch 62/100
# 5243/5243 - 1s - loss: 0.2472 - accuracy: 0.8926
# Epoch 63/100
# 5243/5243 - 1s - loss: 0.2557 - accuracy: 0.8850
# Epoch 64/100
# 5243/5243 - 1s - loss: 0.2556 - accuracy: 0.8879
# Epoch 65/100
# 5243/5243 - 1s - loss: 0.2484 - accuracy: 0.8898
# Epoch 66/100
# 5243/5243 - 1s - loss: 0.2429 - accuracy: 0.8928
# Epoch 67/100
# 5243/5243 - 1s - loss: 0.2376 - accuracy: 0.8959
# Epoch 68/100
# 5243/5243 - 1s - loss: 0.2396 - accuracy: 0.8966
# Epoch 69/100
# 5243/5243 - 1s - loss: 0.2398 - accuracy: 0.8936
# Epoch 70/100
# 5243/5243 - 1s - loss: 0.2432 - accuracy: 0.8947
# Epoch 71/100
# 5243/5243 - 1s - loss: 0.2392 - accuracy: 0.8957
# Epoch 72/100
# 5243/5243 - 1s - loss: 0.2379 - accuracy: 0.8947
# Epoch 73/100
# 5243/5243 - 1s - loss: 0.2442 - accuracy: 0.8903
# Epoch 74/100
# 5243/5243 - 1s - loss: 0.2376 - accuracy: 0.8972
# Epoch 75/100
# 5243/5243 - 1s - loss: 0.2415 - accuracy: 0.8930
# Epoch 76/100
# 5243/5243 - 1s - loss: 0.2418 - accuracy: 0.8917
# Epoch 77/100
# 5243/5243 - 1s - loss: 0.2374 - accuracy: 0.8928
# Epoch 78/100
# 5243/5243 - 1s - loss: 0.2471 - accuracy: 0.8917
# Epoch 79/100
# 5243/5243 - 1s - loss: 0.2357 - accuracy: 0.8974
# Epoch 80/100
# 5243/5243 - 1s - loss: 0.2420 - accuracy: 0.8919
# Epoch 81/100
# 5243/5243 - 1s - loss: 0.2372 - accuracy: 0.8947
# Epoch 82/100
# 5243/5243 - 1s - loss: 0.2397 - accuracy: 0.8915
# Epoch 83/100
# 5243/5243 - 1s - loss: 0.2364 - accuracy: 0.8972
# Epoch 84/100
# 5243/5243 - 1s - loss: 0.2320 - accuracy: 0.8947
# Epoch 85/100
# 5243/5243 - 1s - loss: 0.2368 - accuracy: 0.8957
# Epoch 86/100
# 5243/5243 - 1s - loss: 0.2360 - accuracy: 0.8951
# Epoch 87/100
# 5243/5243 - 1s - loss: 0.2310 - accuracy: 0.8981
# Epoch 88/100
# 5243/5243 - 1s - loss: 0.2417 - accuracy: 0.8894
# Epoch 89/100
# 5243/5243 - 1s - loss: 0.2322 - accuracy: 0.8957
# Epoch 90/100
# 5243/5243 - 1s - loss: 0.2290 - accuracy: 0.8951
# Epoch 91/100
# 5243/5243 - 1s - loss: 0.2329 - accuracy: 0.8964
# Epoch 92/100
# 5243/5243 - 1s - loss: 0.2295 - accuracy: 0.8978
# Epoch 93/100
# 5243/5243 - 1s - loss: 0.2337 - accuracy: 0.8968
# Epoch 94/100
# 5243/5243 - 0s - loss: 0.2278 - accuracy: 0.8981
# Epoch 95/100
# 5243/5243 - 1s - loss: 0.2323 - accuracy: 0.8930
# Epoch 96/100
# 5243/5243 - 1s - loss: 0.2295 - accuracy: 0.8964
# Epoch 97/100
# 5243/5243 - 1s - loss: 0.2270 - accuracy: 0.8989
# Epoch 98/100
# 5243/5243 - 1s - loss: 0.2274 - accuracy: 0.8983
# Epoch 99/100
# 5243/5243 - 1s - loss: 0.2294 - accuracy: 0.8961
# Epoch 100/100
# 5243/5243 - 1s - loss: 0.2255 - accuracy: 0.8999

# %% [markdown]
# ## Quantifying the Model

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1748 - 0s - loss: 0.2514 - accuracy: 0.9062
# Normal Neural Network - Loss: 0.2513811722636496, Accuracy: 0.9061784744262695

# %% [markdown]
# ## Predictions

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE']

# %% [markdown]
# # Save the Model

# %%
# Save the model
model.save("Deeplearning.h5")

# %%
# !which python
# Out:
# /c/Users/nick/anaconda3/envs/PythonAdv/python
